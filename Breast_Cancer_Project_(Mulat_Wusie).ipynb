# %%
# @title Default title text
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Breast Cancer.csv.zip')

# %%
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
#      smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0            0.11840           0.27760         0.30010              0.14710
# 1            0.08474           0.07864         0.08690              0.07017
# 2            0.10960           0.15990         0.19740              0.12790
# 3            0.14250           0.28390         0.24140              0.10520
# 4            0.10030           0.13280         0.19800              0.10430
# ..               ...               ...             ...                  ...
# 564          0.11100           0.11590         0.24390              0.13890
# 565          0.09780           0.10340         0.14400              0.09791
# 566          0.08455           0.10230         0.09251              0.05302
# 567          0.11780           0.27700         0.35140              0.15200
# 568          0.05263           0.04362         0.00000              0.00000
#
#      ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0    ...          17.33           184.60      2019.0           0.16220
# 1    ...          23.41           158.80      1956.0           0.12380
# 2    ...          25.53           152.50      1709.0           0.14440
# 3    ...          26.50            98.87       567.7           0.20980
# 4    ...          16.67           152.20      1575.0           0.13740
# ..   ...            ...              ...         ...               ...
# 564  ...          26.40           166.10      2027.0           0.14100
# 565  ...          38.25           155.00      1731.0           0.11660
# 566  ...          34.12           126.70      1124.0           0.11390
# 567  ...          39.42           184.60      1821.0           0.16500
# 568  ...          30.37            59.16       268.6           0.08996
#
#      compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.66560           0.7119                0.2654          0.4601
# 1              0.18660           0.2416                0.1860          0.2750
# 2              0.42450           0.4504                0.2430          0.3613
# 3              0.86630           0.6869                0.2575          0.6638
# 4              0.20500           0.4000                0.1625          0.2364
# ..                 ...              ...                   ...             ...
# 564            0.21130           0.4107                0.2216          0.2060
# 565            0.19220           0.3215                0.1628          0.2572
# 566            0.30940           0.3403                0.1418          0.2218
# 567            0.86810           0.9387                0.2650          0.4087
# 568            0.06444           0.0000                0.0000          0.2871
#
#      fractal_dimension_worst  Unnamed: 32
# 0                    0.11890          NaN
# 1                    0.08902          NaN
# 2                    0.08758          NaN
# 3                    0.17300          NaN
# 4                    0.07678          NaN
# ..                       ...          ...
# 564                  0.07115          NaN
# 565                  0.06637          NaN
# 566                  0.07820          NaN
# 567                  0.12400          NaN
# 568                  0.07039          NaN
#
# [569 rows x 33 columns]

# %%
df.shape
# Out:
# (569, 33)

# %%
sns.heatmap(df.isnull())# here this code explains Data doesn't contain any Null values
# Out:
# <Axes: >

# %% [markdown]
# ###### check the null values

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# Unnamed: 32                569
# dtype: int64

# %%
df.drop(['id'],axis=1,inplace=True)
df.shape #col-=1
# Out:
# (569, 32)

# %% [markdown]
# ###### now we are deal with this 'radius_mean','radius_mean','radius_mean by passing the code

# %%
df[['radius_mean','radius_mean','radius_mean']]
# Out:
#      radius_mean  radius_mean  radius_mean
# 0          17.99        17.99        17.99
# 1          20.57        20.57        20.57
# 2          19.69        19.69        19.69
# 3          11.42        11.42        11.42
# 4          20.29        20.29        20.29
# ..           ...          ...          ...
# 564        21.56        21.56        21.56
# 565        20.13        20.13        20.13
# 566        16.60        16.60        16.60
# 567        20.60        20.60        20.60
# 568         7.76         7.76         7.76
#
# [569 rows x 3 columns]
# WARNING:root:Quickchart encountered unexpected dtypes in columns: "(['radius_mean', 'radius_mean', 'radius_mean'],)"

# %%
df.drop(['perimeter_mean','area_mean'],axis=1,inplace=True)
df.shape #col-=2 we drop the second column
# Out:
# (569, 30)

# %% [markdown]
# ###### now see the df.columns

# %%
df.columns
# Out:
# Index(['diagnosis', 'radius_mean', 'texture_mean', 'smoothness_mean',
#        'compactness_mean', 'concavity_mean', 'concave points_mean',
#        'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se',
#        'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se',
#        'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst', 'Unnamed: 32'],
#       dtype='object')

# %%
df[['radius_worst','perimeter_worst','area_worst']]
# Out:
#      radius_worst  perimeter_worst  area_worst
# 0          25.380           184.60      2019.0
# 1          24.990           158.80      1956.0
# 2          23.570           152.50      1709.0
# 3          14.910            98.87       567.7
# 4          22.540           152.20      1575.0
# ..            ...              ...         ...
# 564        25.450           166.10      2027.0
# 565        23.690           155.00      1731.0
# 566        18.980           126.70      1124.0
# 567        25.740           184.60      1821.0
# 568         9.456            59.16       268.6
#
# [569 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['radius_worst'].plot(kind='hist', bins=20, title='radius_worst')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['perimeter_worst'].plot(kind='hist', bins=20, title='perimeter_worst')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['area_worst'].plot(kind='hist', bins=20, title='area_worst')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='index', y='radius_worst', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='radius_worst', y='perimeter_worst', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='perimeter_worst', y='area_worst', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['radius_worst']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('radius_worst')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['perimeter_worst']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('perimeter_worst')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['area_worst']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('area_worst')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_11['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_12['radius_worst'].plot(kind='line', figsize=(8, 4), title='radius_worst')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['perimeter_worst'].plot(kind='line', figsize=(8, 4), title='perimeter_worst')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['area_worst'].plot(kind='line', figsize=(8, 4), title='area_worst')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ###### here above you can see 'radius_worst','perimeter_worst','area_worst' have the same info so we can drop 2 of them

# %%
df.drop(['perimeter_worst','area_worst'],axis=1,inplace=True)
df.shape #col-=2
# Out:
# (569, 28)

# %%
df[['radius_se','perimeter_se','area_se']]
# Out:
#      radius_se  perimeter_se  area_se
# 0       1.0950         8.589   153.40
# 1       0.5435         3.398    74.08
# 2       0.7456         4.585    94.03
# 3       0.4956         3.445    27.23
# 4       0.7572         5.438    94.44
# ..         ...           ...      ...
# 564     1.1760         7.673   158.70
# 565     0.7655         5.203    99.04
# 566     0.4564         3.425    48.55
# 567     0.7260         5.772    86.22
# 568     0.3857         2.548    19.15
#
# [569 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['radius_se'].plot(kind='hist', bins=20, title='radius_se')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_17['perimeter_se'].plot(kind='hist', bins=20, title='perimeter_se')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_18['area_se'].plot(kind='hist', bins=20, title='area_se')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_19.plot(kind='scatter', x='index', y='radius_se', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_20.plot(kind='scatter', x='radius_se', y='perimeter_se', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_21.plot(kind='scatter', x='perimeter_se', y='area_se', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['radius_se']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_22.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('radius_se')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['perimeter_se']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_23.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('perimeter_se')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['index']
#   ys = series['area_se']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_24.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('area_se')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_25.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_26['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_27['radius_se'].plot(kind='line', figsize=(8, 4), title='radius_se')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_28['perimeter_se'].plot(kind='line', figsize=(8, 4), title='perimeter_se')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_29['area_se'].plot(kind='line', figsize=(8, 4), title='area_se')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ###### here above 'radius_se','perimeter_se','area_se' have the same info so we can drop 2 of them

# %%
df.drop(['perimeter_se','area_se'],axis=1,inplace=True)
df.shape #col-=2
# Out:
# (569, 26)

# %% [markdown]
# ######  now lets visualizing relationships in a dataset

# %%
df_temp=df.drop(['diagnosis'],axis=1)
plt.figure(figsize=(20, 15))
sns.heatmap(df_temp.corr(), annot=True)
plt.show()

# %% [markdown]
# ###### the correlation coefficient is close to 1, it shows a strong positive linear relationship, so we can drop one of them

# %%
corr_coeff = df['smoothness_mean'].corr(df['smoothness_worst'])
print(f"Pearson correlation coefficient between 'smoothness_mean', 'smoothness_worst' is : {corr_coeff}")
# Out:
# Pearson correlation coefficient between 'smoothness_mean', 'smoothness_worst' is : 0.805324195494363

# %%
corr_coeff = df['symmetry_mean'].corr(df['symmetry_worst'])
print(f"Pearson correlation coefficient between 'symmetry_mean', 'symmetry_worst' is : {corr_coeff}")
# Out:
# Pearson correlation coefficient between 'symmetry_mean', 'symmetry_worst' is : 0.6998257976437305

# %%
corr_coeff = df['concave points_worst'].corr(df['concave points_mean'])
print(f"Pearson correlation coefficient between 'radius_mean', 'radius_worst' is : {corr_coeff}")
# Out:
# Pearson correlation coefficient between 'radius_mean', 'radius_worst' is : 0.9101553142985933

# %%
corr_coeff = df['texture_mean'].corr(df['texture_worst'])
print(f"Pearson correlation coefficient between 'texture_mean', 'texture_worst' is : {corr_coeff}")
# Out:
# Pearson correlation coefficient between 'texture_mean', 'texture_worst' is : 0.912044588840421

# %%
sns.set(style="whitegrid")
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Plot 1
sns.scatterplot(x='smoothness_mean', y='smoothness_worst', data=df, ax=axes[0], color='green')
axes[0].set_title('Smoothness Mean vs. Smoothness Worst')
axes[0].set_xlabel('Smoothness Mean')
axes[0].set_ylabel('Smoothness Worst')

# Plot 2
sns.scatterplot(x='concavity_mean', y='concave points_mean', data=df, ax=axes[1], color='red')
axes[1].set_title('Concavity Mean vs. Concave Points Mean')
axes[1].set_xlabel('Concavity Mean')
axes[1].set_ylabel('Concave Points Mean')

# Plot 3
sns.scatterplot(x='concavity_worst', y='concave points_worst', data=df, ax=axes[2])
axes[2].set_title('Concavity Worst vs. Concave Points Worst')
axes[2].set_xlabel('Concavity Worst')
axes[2].set_ylabel('Concave Points Worst')

plt.tight_layout()
plt.show()

# %% [markdown]
# ###### NOW we can drop one col from 2 cols

# %%
df.drop(['radius_worst','concave points_mean','texture_worst','symmetry_worst','smoothness_worst'],axis=1,inplace=True)

# %% [markdown]
# ###### now lets do  Target  Col for "diagnosis"¶

# %%
df['diagnosis']
# Out:
# 0      M
# 1      M
# 2      M
# 3      M
# 4      M
#       ..
# 564    M
# 565    M
# 566    M
# 567    M
# 568    B
# Name: diagnosis, Length: 569, dtype: object

# %%
df['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %% [markdown]
# ###### Col 'diagnosis' has 2 values {M,B} M for Malignant, B for Benign

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(8, 6))
sns.countplot(x='diagnosis', data=df, palette='Set3')

plt.title('Distribution of Diagnosis')
plt.xlabel('Diagnosis')
plt.ylabel('Count')

# Display the count values on top of the bars
for p in plt.gca().patches:
    plt.gca().annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='center', xytext=(0, 10), textcoords='offset points')


plt.show()
# Out:
# <ipython-input-25-1a4486445c50>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='diagnosis', data=df, palette='Set3')

# %%
df['diagnosis']=df['diagnosis'].map({'M': 0, 'B': 1})
df['diagnosis']
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 564    0
# 565    0
# 566    0
# 567    0
# 568    1
# Name: diagnosis, Length: 569, dtype: int64

# %% [markdown]
# ###### this part we are doing Feature and Target Selectionof data sets

# %%
X=df.drop(['diagnosis'],axis=1)
y=df['diagnosis']
X
# Out:
#      radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0          17.99         10.38          0.11840           0.27760
# 1          20.57         17.77          0.08474           0.07864
# 2          19.69         21.25          0.10960           0.15990
# 3          11.42         20.38          0.14250           0.28390
# 4          20.29         14.34          0.10030           0.13280
# ..           ...           ...              ...               ...
# 564        21.56         22.39          0.11100           0.11590
# 565        20.13         28.25          0.09780           0.10340
# 566        16.60         28.08          0.08455           0.10230
# 567        20.60         29.33          0.11780           0.27700
# 568         7.76         24.54          0.05263           0.04362
#
#      concavity_mean  symmetry_mean  fractal_dimension_mean  radius_se  \
# 0           0.30010         0.2419                 0.07871     1.0950
# 1           0.08690         0.1812                 0.05667     0.5435
# 2           0.19740         0.2069                 0.05999     0.7456
# 3           0.24140         0.2597                 0.09744     0.4956
# 4           0.19800         0.1809                 0.05883     0.7572
# ..              ...            ...                     ...        ...
# 564         0.24390         0.1726                 0.05623     1.1760
# 565         0.14400         0.1752                 0.05533     0.7655
# 566         0.09251         0.1590                 0.05648     0.4564
# 567         0.35140         0.2397                 0.07016     0.7260
# 568         0.00000         0.1587                 0.05884     0.3857
#
#      texture_se  smoothness_se  compactness_se  concavity_se  \
# 0        0.9053       0.006399         0.04904       0.05373
# 1        0.7339       0.005225         0.01308       0.01860
# 2        0.7869       0.006150         0.04006       0.03832
# 3        1.1560       0.009110         0.07458       0.05661
# 4        0.7813       0.011490         0.02461       0.05688
# ..          ...            ...             ...           ...
# 564      1.2560       0.010300         0.02891       0.05198
# 565      2.4630       0.005769         0.02423       0.03950
# 566      1.0750       0.005903         0.03731       0.04730
# 567      1.5950       0.006522         0.06158       0.07117
# 568      1.4280       0.007189         0.00466       0.00000
#
#      concave points_se  symmetry_se  fractal_dimension_se  compactness_worst  \
# 0              0.01587      0.03003              0.006193            0.66560
# 1              0.01340      0.01389              0.003532            0.18660
# 2              0.02058      0.02250              0.004571            0.42450
# 3              0.01867      0.05963              0.009208            0.86630
# 4              0.01885      0.01756              0.005115            0.20500
# ..                 ...          ...                   ...                ...
# 564            0.02454      0.01114              0.004239            0.21130
# 565            0.01678      0.01898              0.002498            0.19220
# 566            0.01557      0.01318              0.003892            0.30940
# 567            0.01664      0.02324              0.006185            0.86810
# 568            0.00000      0.02676              0.002783            0.06444
#
#      concavity_worst  concave points_worst  fractal_dimension_worst  \
# 0             0.7119                0.2654                  0.11890
# 1             0.2416                0.1860                  0.08902
# 2             0.4504                0.2430                  0.08758
# 3             0.6869                0.2575                  0.17300
# 4             0.4000                0.1625                  0.07678
# ..               ...                   ...                      ...
# 564           0.4107                0.2216                  0.07115
# 565           0.3215                0.1628                  0.06637
# 566           0.3403                0.1418                  0.07820
# 567           0.9387                0.2650                  0.12400
# 568           0.0000                0.0000                  0.07039
#
#      Unnamed: 32
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 564          NaN
# 565          NaN
# 566          NaN
# 567          NaN
# 568          NaN
#
# [569 rows x 20 columns]

# %% [markdown]
# ######  here this part Normalizing the Data

# %%
from sklearn.preprocessing import  StandardScaler

scl =StandardScaler()
X_scaled = scl.fit_transform(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1047: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1052: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/extmath.py:1072: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %% [markdown]
# ###### split the data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled,y,test_size=.2,random_state=42)

# %%
X_train
# Out:
# array([[-1.44798723, -0.45602336,  0.72871411, ...,  0.91959172,
#          1.85943247,         nan],
#        [ 1.97750799,  1.69418666,  1.26245493, ...,  2.6752184 ,
#          2.46346488,         nan],
#        [-1.40708919, -1.26351565, -1.36283822, ..., -0.97048581,
#          0.05287682,         nan],
#        ...,
#        [ 0.04621146, -0.57470379, -2.28229573, ..., -1.23756033,
#         -1.26047806,         nan],
#        [-0.04183295,  0.07687501,  0.68601485, ...,  1.03683652,
#          1.19444266,         nan],
#        [-0.5530585 ,  0.28631105, -1.15503513, ..., -0.61357437,
#         -0.84042616,         nan]])

# %%
X_test
# Out:
# array([[-0.47069438, -0.16048584,  0.23411429, ..., -0.19956318,
#          0.19695794,         nan],
#        [ 1.36687747,  0.47014935, -0.44622733, ...,  0.97897545,
#         -1.00057787,         nan],
#        [ 0.37850807,  0.04429607,  0.91374426, ...,  0.56024403,
#         -0.20813168,         nan],
#        ...,
#        [-0.74050787, -1.01451947,  0.35153727, ..., -0.28209134,
#         -0.3245049 ,         nan],
#        [ 0.02633046,  1.99205126, -1.00558771, ..., -0.49358878,
#         -0.33170895,         nan],
#        [ 1.87526288,  2.75300221, -0.1188663 , ...,  0.78102969,
#         -0.0978542 ,         nan]])

# %%
y_train
# Out:
# 68     1
# 181    0
# 63     1
# 248    1
# 60     1
#       ..
# 71     1
# 106    1
# 270    1
# 435    0
# 102    1
# Name: diagnosis, Length: 455, dtype: int64

# %%
y_test
# Out:
# 204    1
# 70     0
# 131    0
# 431    1
# 540    1
#       ..
# 486    1
# 75     0
# 249    1
# 238    1
# 265    0
# Name: diagnosis, Length: 114, dtype: int64

# %% [markdown]
# ###### logistic regression fitting and prediction

# %%
from sklearn.linear_model import LogisticRegression
log_cls = LogisticRegression(random_state=42)

# %%
log_cls
# Out:
# LogisticRegression(random_state=42)

# %%
print(log_cls)
# Out:
# LogisticRegression(random_state=42)
